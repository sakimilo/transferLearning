# %%
import tensorflow as tf
from tensorflow import keras

import numpy as np
import matplotlib.pyplot as plt

print(tf.__version__)
# Out:
# 1.13.1

# %% [markdown]
# ### Load Fashion data!

# %%
fashion_mnist_handler = keras.datasets.fashion_mnist
(train_images, train_labels), (test_images, test_labels) = fashion_mnist_handler.load_data()

# %%
# %ls -lh ~/.keras/datasets/fashion-mnist
# Out:
# total 61888
# -rw-r--r--  1 lingyit  staff   4.2M May 28 13:10 t10k-images-idx3-ubyte.gz
# -rw-r--r--  1 lingyit  staff   5.0K May 28 13:10 t10k-labels-idx1-ubyte.gz
# -rw-r--r--  1 lingyit  staff    25M May 28 13:10 train-images-idx3-ubyte.gz
# -rw-r--r--  1 lingyit  staff    29K May 28 13:09 train-labels-idx1-ubyte.gz

# %%
type(train_images), type(train_labels), type(test_images), type(test_labels)
# Out:
# (numpy.ndarray, numpy.ndarray, numpy.ndarray, numpy.ndarray)

# %%
train_images.shape, train_labels.shape, test_images.shape, test_labels.shape
# Out:
# ((60000, 28, 28), (60000,), (10000, 28, 28), (10000,))

# %%
train_labels[:10], test_labels[:10]
# Out:
# (array([9, 0, 0, 3, 0, 2, 7, 2, 5, 5], dtype=uint8),
#  array([9, 2, 1, 1, 6, 1, 4, 6, 5, 7], dtype=uint8))

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 
               'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
plt.figure()
plt.imshow(train_images[0])
plt.colorbar()
plt.grid(False)
plt.show()

# %%
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i], cmap=plt.cm.binary)
    plt.xlabel(class_names[train_labels[i]])

plt.suptitle('Top 25 images', y=0.92, fontsize=16)
plt.show()
